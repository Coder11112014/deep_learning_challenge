# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import pandas as pd
import tensorflow as tf

#  Import and read the charity_data.csv.
import pandas as pd 
alpha_df = pd.read_csv("./Resources/charity_data.csv")
alpha_df.head()
# Out:
#         EIN                                      NAME APPLICATION_TYPE  \
# 0  10520599              BLUE KNIGHTS MOTORCYCLE CLUB              T10
# 1  10531628    AMERICAN CHESAPEAKE CLUB CHARITABLE TR               T3
# 2  10547893        ST CLOUD PROFESSIONAL FIREFIGHTERS               T5
# 3  10553066            SOUTHSIDE ATHLETIC ASSOCIATION               T3
# 4  10556103  GENETIC RESEARCH INSTITUTE OF THE DESERT               T3
#
#         AFFILIATION CLASSIFICATION      USE_CASE  ORGANIZATION  STATUS  \
# 0       Independent          C1000    ProductDev   Association       1
# 1       Independent          C2000  Preservation  Co-operative       1
# 2  CompanySponsored          C3000    ProductDev   Association       1
# 3  CompanySponsored          C2000  Preservation         Trust       1
# 4       Independent          C1000     Heathcare         Trust       1
#
#       INCOME_AMT SPECIAL_CONSIDERATIONS  ASK_AMT  IS_SUCCESSFUL
# ...

# %%
# pip install tensorflow

# %%
# Drop the non-beneficial ID columns, 'EIN' and 'NAME'.
alpha_df = alpha_df.drop(['EIN', 'NAME'], axis=1)
alpha_df.head()
# Out:
#   APPLICATION_TYPE       AFFILIATION CLASSIFICATION      USE_CASE  \
# 0              T10       Independent          C1000    ProductDev
# 1               T3       Independent          C2000  Preservation
# 2               T5  CompanySponsored          C3000    ProductDev
# 3               T3  CompanySponsored          C2000  Preservation
# 4               T3       Independent          C1000     Heathcare
#
#    ORGANIZATION  STATUS     INCOME_AMT SPECIAL_CONSIDERATIONS  ASK_AMT  \
# 0   Association       1              0                      N     5000
# 1  Co-operative       1         1-9999                      N   108590
# 2   Association       1              0                      N     5000
# 3         Trust       1    10000-24999                      N     6692
# 4         Trust       1  100000-499999                      N   142590
#
#    IS_SUCCESSFUL
# 0              1
# 1              1
# 2              0
# 3              1
# 4              1

# %%
# Determine the number of unique values in each column.
alpha_df.nunique(axis=0)
# Out:
# APPLICATION_TYPE            17
# AFFILIATION                  6
# CLASSIFICATION              71
# USE_CASE                     5
# ORGANIZATION                 4
# STATUS                       2
# INCOME_AMT                   9
# SPECIAL_CONSIDERATIONS       2
# ASK_AMT                   8747
# IS_SUCCESSFUL                2
# dtype: int64

# %%
# Look at APPLICATION_TYPE value counts for binning
alpha_df['APPLICATION_TYPE'].value_counts()
# Out:
# T3     27037
# T4      1542
# T6      1216
# T5      1173
# T19     1065
# T8       737
# T7       725
# T10      528
# T9       156
# T13       66
# T12       27
# T2        16
# T25        3
# T14        3
# T29        2
# T15        2
# T17        1
# Name: APPLICATION_TYPE, dtype: int64

# %%
# Choose a cutoff value and create a list of application types to be replaced
# use the variable name `application_types_to_replace`
application_types_to_replace = ['T25','T14','T15','T29','T17','T2','T12','T13','T9']

# Replace in dataframe
for app in application_types_to_replace:
    alpha_df['APPLICATION_TYPE'] = alpha_df['APPLICATION_TYPE'].replace(app,"Other")

# Check to make sure binning was successful
alpha_df['APPLICATION_TYPE'].value_counts()
# Out:
# T3       27037
# T4        1542
# T6        1216
# T5        1173
# T19       1065
# T8         737
# T7         725
# T10        528
# Other      276
# Name: APPLICATION_TYPE, dtype: int64

# %%
# Look at CLASSIFICATION value counts for binning
alpha_df['CLASSIFICATION'].value_counts()
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
#          ...
# C4120        1
# C8210        1
# C2561        1
# C4500        1
# C2150        1
# Name: CLASSIFICATION, Length: 71, dtype: int64

# %%
# You may find it helpful to look at CLASSIFICATION value counts >1
alpha_df['CLASSIFICATION'].value_counts() >1
# Out:
# C1000     True
# C2000     True
# C1200     True
# C3000     True
# C2100     True
#          ...
# C4120    False
# C8210    False
# C2561    False
# C4500    False
# C2150    False
# Name: CLASSIFICATION, Length: 71, dtype: bool

# %%
# Choose a cutoff value and create a list of classifications to be replaced
# use the variable name `classifications_to_replace`
classifications_to_replace = ['C5000','C4000','C1700','C7100','C2800','C2700','C1270','C7200','C6000', 'C1238', 'C7120', 'C1800', 'C4100', 'C1400', 'C2300','C8200', 'C1500', 'C7210', 'C1300', 'C1230', 'C1280', 'C1240','C2710', 'C2561', 'C1250', 'C8000', 'C1245', 'C1260', 'C1235','C1720', 'C1257', 'C4500', 'C2400', 'C8210', 'C1600', 'C1278','C1237', 'C4120', 'C2170', 'C1728', 'C1732', 'C2380', 'C1283','C1570', 'C2500', 'C1267', 'C3700', 'C1580', 'C2570', 'C1256','C1236', 'C1234', 'C1246', 'C2190', 'C4200']

# Replace in dataframe
for cls in classifications_to_replace:
    alpha_df['CLASSIFICATION'] = alpha_df['CLASSIFICATION'].replace(cls,"Other")
    
# Check to make sure binning was successful
alpha_df['CLASSIFICATION'].value_counts()
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
# Other     1471
# C7000      777
# C0           3
# C3200        2
# C5200        1
# C1370        1
# C2600        1
# C1248        1
# C6100        1
# C1820        1
# C1900        1
# C2150        1
# Name: CLASSIFICATION, dtype: int64

# %%
# Convert categorical data to numeric with `pd.get_dummies`
alpha_dummies = pd.get_dummies(alpha_df)
alpha_dummies.head()
# Out:
#    STATUS  ASK_AMT  IS_SUCCESSFUL  APPLICATION_TYPE_Other  \
# 0       1     5000              1                       0
# 1       1   108590              1                       0
# 2       1     5000              0                       0
# 3       1     6692              1                       0
# 4       1   142590              1                       0
#
#    APPLICATION_TYPE_T10  APPLICATION_TYPE_T19  APPLICATION_TYPE_T3  \
# 0                     1                     0                    0
# 1                     0                     0                    1
# 2                     0                     0                    0
# 3                     0                     0                    1
# 4                     0                     0                    1
#
#    APPLICATION_TYPE_T4  APPLICATION_TYPE_T5  APPLICATION_TYPE_T6  ...  \
# 0                    0                    0                    0  ...
# ...

# %%
# Split our preprocessed data into our features and target arrays
y = alpha_dummies['IS_SUCCESSFUL']
X = alpha_dummies.drop(['IS_SUCCESSFUL'],axis=1)
# Split the preprocessed data into a training and testing dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=50)

# %%
# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %% [markdown]
# # Compile, Train and Evaluate the Model

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
num_features = len(X_train_scaled[0])
hidden_nodes_layer1 = 50
hidden_nodes_layer2 = 70
# hidden_nodes_layer3= 90

nn = tf.keras.models.Sequential()

# First hidden layer
nn.add(tf.keras.layers.Dense(units=hidden_nodes_layer1, input_dim=num_features, activation='relu'))

# Second hidden layer
nn.add(tf.keras.layers.Dense(units=hidden_nodes_layer2, activation='relu'))


# Output layer
nn.add(tf.keras.layers.Dense(units=1, activation='sigmoid'))

# Check the structure of the model
nn.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense (Dense)               (None, 50)                2750
#
#  dense_1 (Dense)             (None, 70)                3570
#
#  dense_2 (Dense)             (None, 1)                 71
#
# ...
# Total params: 6,391
# Trainable params: 6,391
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile the model
nn.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
# Train the model
fit_model = nn.fit(X_train_scaled,y_train,epochs=500)
# Out:
# Epoch 1/500
# 804/804 [==============================] - 1s 711us/step - loss: 0.5361 - accuracy: 0.7379
# Epoch 2/500
# 804/804 [==============================] - 1s 698us/step - loss: 0.5358 - accuracy: 0.7383
# Epoch 3/500
# 804/804 [==============================] - 1s 734us/step - loss: 0.5362 - accuracy: 0.7383
# Epoch 4/500
# 804/804 [==============================] - 1s 713us/step - loss: 0.5363 - accuracy: 0.7369
# Epoch 5/500
# 804/804 [==============================] - 1s 688us/step - loss: 0.5361 - accuracy: 0.7376
# Epoch 6/500
# 804/804 [==============================] - 1s 684us/step - loss: 0.5364 - accuracy: 0.7378
# Epoch 7/500
# 804/804 [==============================] - 1s 692us/step - loss: 0.5360 - accuracy: 0.7378
# Epoch 8/500
# 804/804 [==============================] - 1s 688us/step - loss: 0.5360 - accuracy: 0.7371
# Epoch 9/500
# 804/804 [==============================] - 1s 687us/step - loss: 0.5355 - accuracy: 0.7377
# Epoch 10/500
# ...

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 268/268 - 0s - loss: 1.0040 - accuracy: 0.7402 - 251ms/epoch - 937us/step
# Loss: 1.0040357112884521, Accuracy: 0.7401749491691589

# %%
# Export our model to HDF5 file
nn.save("AlphabetSoupCharity_Optimization2.h5")
